# %%
import pandas as pnd
import numpy as np

# %%
fichier = pnd.read_csv("sonar.all-data.csv")

# %%
print(fichier.columns.values)
# Out:
# ['0.0200' '0.0371' '0.0428' '0.0207' '0.0954' '0.0986' '0.1539' '0.1601'
#  '0.3109' '0.2111' '0.1609' '0.1582' '0.2238' '0.0645' '0.0660' '0.2273'
#  '0.3100' '0.2999' '0.5078' '0.4797' '0.5783' '0.5071' '0.4328' '0.5550'
#  '0.6711' '0.6415' '0.7104' '0.8080' '0.6791' '0.3857' '0.1307' '0.2604'
#  '0.5121' '0.7547' '0.8537' '0.8507' '0.6692' '0.6097' '0.4943' '0.2744'
#  '0.0510' '0.2834' '0.2825' '0.4256' '0.2641' '0.1386' '0.1051' '0.1343'
#  '0.0383' '0.0324' '0.0232' '0.0027' '0.0065' '0.0159' '0.0072' '0.0167'
#  '0.0180' '0.0084' '0.0090' '0.0032' 'R']

# %%
print(fichier.shape)
# Out:
# (207, 61)

# %%
donnees = pnd.read_csv( "sonar.all-data.csv", names=["F1", "F2", "F3", "F4", "F5", "F6", "F7", "F8", "F9", "F10",
                                        "F11 ", "F12", "F13", "F14", "F15", "F16", "F17", "F18", "F19",
                                        "F20", "F21", "F22", "F23", "F24", "F25", "F26", "F27",
                                        "F28", "F29", "F30", "F31", "F32", "F33", "F34", "F35",
                                        "F36", "F37", "F38", "F39", "F40", "F41", "F42", "F43",
                                        "F44", "F45", "F46", "F47", " F48", "F49", "F50",
                                        "F51", "F52", "F53", "F54", "F55", "F56", "F57", "F58",
                                        "F59", "F60", "OBJET"])

# %% [markdown]
# donnees

# %%
print(donnees.head())
# Out:
#        F1      F2      F3     F4      F5       F6     F7      F8      F9   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#       F10  ...     F52     F53     F54     F55     F56     F57     F58  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#       F59     F60  OBJET
# 0  0.0090  0.0032      R
# 1  0.0052  0.0044      R
# ...

# %%
print(donnees.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   F1      208 non-null    float64
#  1   F2      208 non-null    float64
#  2   F3      208 non-null    float64
#  3    F4     208 non-null    float64
#  4   F5      208 non-null    float64
#  5   F6      208 non-null    float64
#  6   F7      208 non-null    float64
#  7   F8      208 non-null    float64
#  8   F9      208 non-null    float64
#  9   F10     208 non-null    float64
#  10  F11     208 non-null    float64
#  11  F12     208 non-null    float64
#  12  F13     208 non-null    float64
#  13  F14     208 non-null    float64
#  14  F15     208 non-null    float64
#  15  F16     208 non-null    float64
#  16  F17     208 non-null    float64
#  17  F18     208 non-null    float64
#  18  F19     208 non-null    float64
#  19  F20     208 non-null    float64
# ...

# %%
print(donnees.describe())
# Out:
#                F1          F2          F3         F4          F5           F6  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#               F7          F8          F9          F10  ...         F51  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
donnees
# Out:
#          F1      F2      F3     F4      F5       F6     F7      F8      F9   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
print(donnees['F2'].describe(), donnees['F3'].describe(), donnees['F4'].describe(), donnees['F5'].describe(), donnees['F6'].describe(), donnees['F7'].describe())
# Out:
# count    208.000000
# mean       0.038437
# std        0.032960
# min        0.000600
# 25%        0.016450
# 50%        0.030800
# 75%        0.047950
# max        0.233900
# Name: F2, dtype: float64 count    208.000000
# mean       0.043832
# std        0.038428
# min        0.001500
# 25%        0.018950
# 50%        0.034300
# 75%        0.057950
# max        0.305900
# Name: F3, dtype: float64 count    208.000000
# mean       0.053892
# std        0.046528
# min        0.005800
# 25%        0.024375
# 50%        0.044050
# 75%        0.064500
# max        0.426400
# Name: F4, dtype: float64 count    208.000000
# mean       0.075202
# std        0.055552
# min        0.006700
# 25%        0.038050
# 50%        0.062500
# 75%        0.100275
# max        0.401000
# Name: F5, dtype: float64 count    208.000000
# mean       0.104570
# std        0.059105
# min        0.010200
# 25%        0.067025
# 50%        0.092150
# 75%        0.134125
# max        0.382300
# ...

# %%
df2_7=donnees[["F2","F3","F4","F5","F6","F7"]]
df2_7.describe()
# Out:
#                F2          F3          F4          F5          F6          F7
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.038437    0.043832    0.053892    0.075202    0.104570    0.121747
# std      0.032960    0.038428    0.046528    0.055552    0.059105    0.061788
# min      0.000600    0.001500    0.005800    0.006700    0.010200    0.003300
# 25%      0.016450    0.018950    0.024375    0.038050    0.067025    0.080900
# 50%      0.030800    0.034300    0.044050    0.062500    0.092150    0.106950
# 75%      0.047950    0.057950    0.064500    0.100275    0.134125    0.154000
# max      0.233900    0.305900    0.426400    0.401000    0.382300    0.372900

# %%
donnees['OBJET'].value_counts()
# Out:
# M    111
# R     97
# Name: OBJET, dtype: int64

# %% [markdown]
# #####

# %%
from sklearn.metrics import confusion_matrix

# %%
donnees["F3"].describe()
# Out:
# count    208.000000
# mean       0.043832
# std        0.038428
# min        0.001500
# 25%        0.018950
# 50%        0.034300
# 75%        0.057950
# max        0.305900
# Name: F3, dtype: float64

# %%
donnees.corr()
# Out:
#             F1        F2        F3        F4        F5        F6        F7  \
# F1    1.000000  0.735896  0.571537  0.491438  0.344797  0.238921  0.260815
# F2    0.735896  1.000000  0.779916  0.606684  0.419669  0.332329  0.279040
# F3    0.571537  0.779916  1.000000  0.781786  0.546141  0.346275  0.190434
# F4    0.491438  0.606684  0.781786  1.000000  0.726943  0.352805  0.246440
# F5    0.344797  0.419669  0.546141  0.726943  1.000000  0.597053  0.335422
# F6    0.238921  0.332329  0.346275  0.352805  0.597053  1.000000  0.702889
# F7    0.260815  0.279040  0.190434  0.246440  0.335422  0.702889  1.000000
# F8    0.355523  0.334615  0.237884  0.246742  0.204006  0.471683  0.675774
# F9    0.353420  0.316733  0.252691  0.247078  0.177906  0.327578  0.470580
# F10   0.318276  0.270782  0.219637  0.237769  0.183219  0.288621  0.425448
# F11   0.344058  0.297065  0.274610  0.271881  0.231684  0.333570  0.396588
# ...
